# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavmishra1/Deep_Learning_with_Keras/blob/master/lstm_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import numpy as np
path = keras.utils.get_file('nietzsche.txt',origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
print(text[0:100])

maxlen = 60
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
	sentences.append(text[i: i + maxlen])
	next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
	for t, char in enumerate(sentence):
		x[i, t, char_indices[char]] = 1
	y[i, char_indices[next_chars[i]]] = 1


from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
	preds = np.asarray(preds).astype('float64')
	preds = np.log(preds) / temperature
	exp_preds = np.exp(preds)
	preds = exp_preds / np.sum(exp_preds)
	probas = np.random.multinomial(1, preds, 1)
	return np.argmax(probas)


import random
import sys
for epoch in range(1, 60):
	print('epoch', epoch)
	model.fit(x, y, batch_size=128, epochs=1)
	start_index = random.randint(0, len(text) - maxlen - 1)
	generated_text = text[start_index: start_index + maxlen]
	print('--- Generating with seed: "' + generated_text + '"')
	for temperature in [0.2, 0.5, 1.0, 1.2]:
		print('------ temperature:', temperature)
		sys.stdout.write(generated_text)
		for i in range(400):
			sampled = np.zeros((1, maxlen, len(chars)))
			for t, char in enumerate(generated_text):
				sampled[0, t, char_indices[char]] = 1.
			preds = model.predict(sampled, verbose=0)[0]
			next_index = sample(preds, temperature)
			next_char = chars[next_index]
			generated_text += next_char
			generated_text = generated_text[1:]
			sys.stdout.write(next_char)
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893
# preface
#
#
# supposing that truth is a woman--what then? is there not ground
# for suspecting that all ph
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# WARNING: Logging before flag parsing goes to stderr.
# W0811 23:24:59.101249 140114937616256 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0811 23:24:59.136202 140114937616256 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0811 23:24:59.150228 140114937616256 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0811 23:24:59.427635 140114937616256 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0811 23:24:59.440226 140114937616256 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# epoch 1
# W0811 23:24:59.665878 140114937616256 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0811 23:25:00.227212 140114937616256 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.9898
# --- Generating with seed: "ave kept the type of
# "man" upon a lower level--they have pre"
# ------ temperature: 0.2
# ave kept the type of
# "man" upon a lower level--they have pressical the same the sair and that the same the spirit and the soul and the soul and is the self to the share the say, the self and soul and the self of the spirit of the same the self that a preficious and the deferent and the self the san the self that is all the servent and all the superal spirit of the self the self to the self the state the self to the same and the state in the same the prasie------ temperature: 0.5
# te the self to the same and the state in the same the prasies of the distrive and the encribles and as to the should religelted and into the in the blated of the significively that has incoluation is soul intating beend as the plotection is the consequence free still a feeling a posself and is is a that that the serfice sought of the are is the sperined at the more of all all soul hand the live the passion of the thire is a profausing as that is districita------ temperature: 1.0
# e passion of the thire is a profausing as that is districitation of the saind ratived as that precivelation, upisten,
# an
# ate bindinglices.
# 1hage is atalucications,
# we toly good that is is signaves waurred neclage. bats, bo deventing
# morgle"
# thempelfy wlat a cruttior; honectations, an inds a  the reagection and
# is to to eviltibiby what rellected his himaping
# this jegagence of sufferings that is in thereby is "wertrajsfes, has indelirable,
# ill precausey atse------ temperature: 1.2
# thereby is "wertrajsfes, has indelirable,
# ill precausey atsealleslaked?
#  questiout as man-any dowing, peryassan truth,
# scheness, thing
# inclusify)?a which nainessciblars" and
# juctrencive certath, and
# discregndation upund as sticr melismemequelationsable be if a  make takan.";--in the
# leads, the lwhighespliatenn, a piles worh? relaygepakic or always thanwast): jurself, hamping as not
# of a whevean the coned all that is
# itsile, peainal murtusanrazing chay toueepoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 134s 669us/step - loss: 1.6362
# --- Generating with seed: "e sense of
# shame. they feel as if one wished to peep under t"
# ------ temperature: 0.2
# e sense of
# shame. they feel as if one wished to peep under the sense of the sense of the sense of the sense of the sense of the contration of the conditions of the sense of the sense of the sense of the extert of the conduct of the most and the men of the contrint of the consequence of the contration of the most prostical the conditions of the more of the sense of the sense of the interrars and the sense of the sense of the sense of the conditions of the s------ temperature: 0.5
# e sense of the sense of the sense of the conditions of the sich a being the condetions of the sense of the conterrory and superation of the trute of the every stropess of the man and momenty, and sered to promen, and here of the anternation of the sense of the conduct of the exceptions for exterted and longer from the experience of been his greself of the great another exceptionsing and there
# is the yet more of the ne sensible or a most to as more in the i------ temperature: 1.0
# he yet more of the ne sensible or a most to as more in the inearmed much that only his own, or ever." in their sinction.
#
#
# 1me must
# petony extemed contrations and , ack extent syitime
# poder. bouther infurreblys is no  ner mosts  the regarded, is i not in evonibure so now in evil, in the shainanic under nobly bad so much o the sube of the resonsar from refuction ot farting
# of suchess pro)tible
# only anol; if impultions, man man do unccectioned is coudics the------ temperature: 1.2
#  anol; if impultions, man man do unccectioned is coudics then
# from must romie fectars.
#
# 1nemomical accorderninguse could
# light--w. thencereblenness it longs. on the firstions
# andycance, at our withiestigns to conduct nich., benebger,.=, (thing more
# heewself and there
# to liont be roror) most delicames ourly the actual stracrity, inher
# himtes,
# as cafficuried to hhogherich know, he hadty loty--but
#
#         onogice mork ablect from excenalatific of noto, the iepoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 130s 649us/step - loss: 1.5476
# --- Generating with seed: "d to himself: who has not already, in my situation, mistaken"
# ------ temperature: 0.2
# d to himself: who has not already, in my situation, mistaken who is the still in the sense to be such a desire the experience of the spirit of the sense of the means of the sense of the faith the schopenhauer: the sense of the fact of the same the strength that the state of the strength and desires of the strength of the strength the state the still destinated the sense of the sense of the sense that the state the german disclusion of the sense of the sens------ temperature: 0.5
# hat the state the german disclusion of the sense of the sense. the being which without the conscience in the stit of the convidion of had the freezed in the strange and desire to the same of the sense with their power
# anawism with such a man belief and are an emilary in his eref the spirit is the same and
# the still the faith to which their man man the dear for the self and suppride to the fact and man and carry faith the man to be at the error fait in ever------ temperature: 1.0
#  man and carry faith the man to be at the error fait in every might has of religion of standause to be disconcese thing that i man believeserriesic. certulise for repustifies of faith ruwt--as man right sight
# its a willings exist the seim
# and
# cated and towne---the "have capition of nother harme
# strungly the kied their fact of this others and valiation
# that diymantice execce and nob-destimation
# one
# soned
# sesult. the
# deleps
# to the suffered in its bese
# the "m------ temperature: 1.2
#
# soned
# sesult. the
# deleps
# to the suffered in its bese
# the "moint philosophy
# christian
# certain what be bely
# bey does i clame talfra; the exercised the visibles earmied uppas
# of his keatified and celturily whide not pactive emawly cuct, yeacteed "ridey lest ge, i ababout. a faith the christoncesble in
# undinated," besasters conceriance,
# and actipurance, are," and foniz, now thehe inwore's eviled heakthime, hy soc. from, somato knool pruons to vablikedness eepepoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 129s 643us/step - loss: 1.5030
# --- Generating with seed: "weetened cruelty in sense and spirit--we shall presumably, i"
# ------ temperature: 0.2
# weetened cruelty in sense and spirit--we shall presumably, in the same and the desire and a distrust and the prefuld to an as and also the same the superianty for the present the sense the destrends and the sense and also the sense of the man as the transsible to the pain to and the man be sense of the faith of the been and the intered and the astemate the sense to the same the and the pride of the precisely to the spirit and the faith of the sense to the ------ temperature: 0.5
# e precisely to the spirit and the faith of the sense to the self-day and man in the senses of the same the displiar to the enterly to the man in the way. in those know which all been such a precised and
# develops that it would strive to all the other of the perfogl the man
# superficial and entain of the commen must be a midus of the destratude of a way a doubt, in the facts of his eath and also pain and successjosoly and convicis and word are to the same and------ temperature: 1.0
#  and successjosoly and convicis and word are to the same and the great very time
# myself and pertual and indecerious
# pain
# things free)s or also stand of scent peace and laten--everythic
# his commend a di entiap": every
# believed to art still hadess is own engulle and temal reintidial dincidened: and have underoldfut with the to dood to cigle. himself, and effect, strongic or
# a morality,
# proophesent deman attention" sore and more pited oowger enemenfully and c------ temperature: 1.2
# eman attention" sore and more pited oowger enemenfully and called nevel of
# the fide aga, fain thather duts.,
# a
# didgure,.
#
# 2utio also of if--an inaccomandness fattering e, han, that dspornirousa
# ensci. it aod certain and toute of the poltenthe syitir traint. they dreadfulute.f
# reashed; god attaine--gnams of have beneval of rand higher concertion the
# human desolity to affer fellow that other fact is self-keve thus.=--matter, hid emprematly ascestion philoverepoch 5
# Epoch 1/1
# 128384/200278 [==================>...........] - ETA: 46s - loss: 1.4655
